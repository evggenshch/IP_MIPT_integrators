# %%
from skimage import color, io

# %%
import luminosity_videoflow
import integration
import cv2

# %%
# !pip install opencv-python

# %%
inst = luminosity_videoflow.VideoFlow("Shoes-sRGB.jpg")

# %%
inst.first_stage_augmentation(num_frames=5)

# %%
print(len(inst.first_stage_frames))
# Out:
# 100

# %%
for i in range(len(inst.first_stage_frames)):
    io.imsave(str(i) + ".png", inst.first_stage_frames[i])

# %%
for i in range(len(inst.second_stage_frames)):
    io.imsave(str(i) + ".png", inst.second_stage_frames[i])

# %%
inst = luminosity_videoflow.VideoFlow("Shoes-sRGB.jpg")
inst.second_stage_augmentation()
metrics, res_img = integration.first_phase_integrator(inst.first_stage_frames)
#print(res_img)
#for i in range(len(inst.first_stage_frames)):
#    io.imsave(str(i) + ".png", inst.second_stage_frames[i])
#io.imsave("res.png", res_img)
print(metrics)
# Out:
# []
# /home/evggenshch/.local/lib/python3.7/site-packages/numpy/core/fromnumeric.py:3257: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /home/evggenshch/.local/lib/python3.7/site-packages/numpy/core/_methods.py:161: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
inst.first_stage_frames[3]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-7-9b7eb29b978c> in <module>
# ----> 1 inst.first_stage_frames[3]
#       2
#       3
#       4
#       5
#
# IndexError: list index out of range

# %%
from matplotlib import pyplot as plt

# %%
import numpy as np

# %%
img = io.imread("Shoes-sRGB.jpg")

# %%
io.imshow(img)
plt.show()

# %%
img
# Out:
# Array([[[  1,   7,   3],
#         [  1,   8,   1],
#         [  0,   7,   0],
#         ...,
#         [ 69, 108,  17],
#         [ 64,  98,  11],
#         [ 39,  77,   2]],
#
#        [[  1,   5,   4],
#         [  1,   6,   2],
#         [  2,   7,   1],
#         ...,
#         [ 46,  90,   3],
#         [ 41,  74,   5],
#         [ 34,  64,   0]],
#
#        [[  0,   4,   5],
#         [  1,   5,   4],
#         [  1,   7,   3],
#         ...,
#         [ 25,  67,   3],
#         [ 38,  67,   0],
#         [ 36,  60,   0]],
#
#        ...,
#
#        [[ 81,  76,  44],
#         [ 42,  40,   1],
#         [ 61, 115,  53],
#         ...,
#         [ 26,  55,   0],
#         [107,  98,  65],
#         [118, 125,  84]],
#
#        [[ 99, 102,  55],
#         [ 41,  32,   3],
#         [ 32,  47,   4],
#         ...,
#         [ 28,  46,   0],
#         [145, 144, 114],
#         [167, 173, 139]],
#
#        [[111,  98,  30],
#         [ 54,  53,   7],
#         [ 47,  51,  16],
#         ...,
#         [ 40,  41,   1],
#         [161, 160, 132],
#         [190, 194, 171]]], dtype=uint8)

# %%
img_transformed = color.rgb2rgbcie(img) #color.rgbcie2rgb()  0.85

# %%
(img_transformed * 255).astype(dtype = np.uint8)
# Out:
# array([[[  1,   7,   3],
#         [  1,   8,   1],
#         [  0,   7,   0],
#         ...,
#         [ 69, 109,  17],
#         [ 64,  98,  11],
#         [ 39,  77,   2]],
#
#        [[  1,   5,   4],
#         [  1,   6,   2],
#         [  2,   7,   1],
#         ...,
#         [ 46,  90,   3],
#         [ 41,  74,   5],
#         [ 34,  64,   0]],
#
#        [[  0,   4,   5],
#         [  1,   5,   4],
#         [  1,   7,   3],
#         ...,
#         [ 25,  67,   3],
#         [ 38,  67,   0],
#         [ 36,  60,   0]],
#
#        ...,
#
#        [[ 81,  76,  44],
#         [ 42,  40,   1],
#         [ 61, 116,  53],
#         ...,
#         [ 26,  55,   0],
#         [108,  98,  65],
#         [119, 126,  84]],
#
#        [[ 99, 103,  55],
#         [ 41,  32,   3],
#         [ 32,  47,   4],
#         ...,
#         [ 28,  46,   0],
#         [146, 145, 115],
#         [168, 174, 140]],
#
#        [[112,  98,  30],
#         [ 54,  53,   7],
#         [ 47,  51,  16],
#         ...,
#         [ 40,  41,   1],
#         [162, 161, 133],
#         [191, 195, 172]]])

# %%
io.imshow((img_transformed * 255).astype(dtype = np.uint8))

# %%
io.imshow((img_transformed * 255).astype(dtype = np.uint8))
plt.show()
# Out:
# /home/evggenshch/anaconda3/lib/python3.7/site-packages/skimage/util/dtype.py:135: UserWarning: Possible precision loss when converting from int64 to float64
#   .format(dtypeobj_in, dtypeobj_out))
# /home/evggenshch/anaconda3/lib/python3.7/site-packages/skimage/io/_plugins/matplotlib_plugin.py:75: UserWarning: Low image data range; displaying image with stretched contrast.
#   warn("Low image data range; displaying image with "

# %%
io.imsave("rgb_shoes.jpg", (color.rgb2rgbcie(img) * 255).astype(dtype = np.uint8))

# %%
io.imsave("srgb_shoes.jpg", (img_transformed * 255).astype(dtype = np.uint8))
